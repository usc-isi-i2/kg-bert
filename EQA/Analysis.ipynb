# %%
import json, random
from collections import Counter
import pandas as pd
import numpy as np
import networkx as nx
from itertools import islice
from tqdm import tqdm
import matplotlib.pyplot as plt
from collections import defaultdict
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %% [markdown]
# # Set Up Folder

# %%
# input
data_dir="eqa_v1"
train_file='%s/train/train.json' % data_dir
val_file='%s/val/val.json' % data_dir
cskg_dim_folder="./data/cskg_dim/cskg_dim.tsv"
wordnet_file="./data/wn/kgtk_wordnet.tsv"

# output
cskg_qa="./data/cskg_dim/eqa_cskg_dim.tsv"

# %% [markdown]
# # Add Triples to each lines

# %%
def load_source(filename):
    # load data
    with open(filename,"r",encoding="utf-8") as f:
        head=f.readline().strip().split("\t")
        data=[]
        for line in f:
            temp=line.strip().split("\t")
            data.append([item.split("|")[0] for item in temp])
            
    return head, data

def k_shortest_paths(G, source, target, k, weight=None):
    return list(islice(nx.shortest_simple_paths(G, source, target, weight=weight), k))

class QAsystem():
    def __init__(self, filename):
        # add data to QAsystem
        with open(filename, 'r') as f:
            self.train=json.load(f)
        
        # build dataframe for QA system
        episodes=self.train["episodes"]

        questions=[]
        qtypes=[]
        answers=[]
        objects=[]
        for x in episodes:
            questions.append(x['question']['question_text'])
            answers.append(x['question']['answer_text'])
            qtypes.append(x['question']['question_type'])
            objects.append([x["goals"][0]["object_name"],x["goals"][0]["room_name"]])

        # build df
        data=zip(questions,answers,qtypes,objects)
        self.df=pd.DataFrame(data)
        self.df.columns=['question', 'answer', 'qtype',"objects"]
        self.df=self.df.drop_duplicates(subset=['question','answer','qtype'])
    
    def build_graph_cskg(self, source):
        # build a cskg graph
        self.G = nx.DiGraph()
        for line in source:
            self.G.add_edge(line[4].replace(" ","_"),line[5].replace(" ","_"),label=line[6],id_=line[2],source=line[8])
            
    def save_file(self, filename):
        # save file to json file
        
        question_triple=dict()
        #build dict
        for row in QA.df.iterrows():
            question_text=row[1].question
            question_triple[question_text]=[row[1].triples_len2,row[1].shortest_path]
            
        episodes=self.train["episodes"]
        for x in episodes:
            x['question']['len2Paths']=question_triple[x['question']['question_text']]
            x['question']['ShortestPath']=question_triple[x['question']['question_text']]
            
        self.train["episodes"]=episodes
        
        with open(filename, 'w') as f:
            json.dump(self.train, f)
            
    def add_cskg2QA(self):
        # add cskg to QA system
        # find object1 and object2 are in the path 2
        len2_paths=[]
        k_paths = []
        # nodes not in graph
        no_source=[]
        
        for objects in tqdm(self.df.objects):
            obj1, obj2=objects

            # check whther both nodes are in the graph. Otherwise, break
            if not self.G.has_node(obj1):
                len2_paths.append([])
                k_paths.append([])

                no_source.append(obj1)
                continue

            if not self.G.has_node(obj2):
                len2_paths.append([x['question']['question_text']])
                k_paths.append([x['question']['question_text']])

                no_source.append(obj2)
                continue
            # find a length 2 path between both nodes
            paths=[]
            paths += list(nx.all_simple_paths(self.G, source=obj1, target=obj2,cutoff=2))
            
            len2_paths.append(paths)

            # find the kth shortest path between two nodes
            temp_path=[]
            temp_path += list(k_shortest_paths(self.G, obj1, obj2, 20))

            k_paths.append(temp_path)
        self.df["triples_len2"]=len2_paths
        self.df["shortest_path"]=k_paths
        
        # filter lines
        # Choose the triples wioth relation: "r/LocatedNear","/r/AtLocation"
        id_reuqire={"/r/LocatedNear","/r/AtLocation"}

        paths_length=[]
        paths_shortest=[]
        for mult_node1, mult_node2 in zip(len2_paths,k_paths):
            items=[]
            for line in mult_node1:
                # check whether the relation in this line is the stisfied relation id
                status=True
                #print(line)
                for i in range(len(line)-1):
                    node1=line[i]
                    node2=line[i+1]
                    edge_detail = self.G[node1][node2]
                    edge_id= edge_detail["id_"]
                    #print(edge_id)
                    if edge_id in id_reuqire:
                        pass
                    else:
                        status=False
                #print(status)        
                if status:
                    new_line=[]
                    for i in range(len(line)-1):
                        node1=line[i]
                        node2=line[i+1]

                        if not new_line:
                            try:
                                new_line+=[node1,self.G[node1][node2]["label"],node2]
                            except:
                                print(node1, node2,line,line[i],line[i+1])
                        else:
                            try:
                                new_line+=[self.G[node1][node2]["label"],node2]
                            except:
                                print(node1, node2,line,line[i],line[i+1])
                else:
                    new_line=[]

                if new_line:
                    items.append(new_line)
            paths_length.append(items)

            items=[]
            for line in mult_node2:
                # check whether the relation in this line is the stisfied relation id
                status=True
                #print(line)
                for i in range(len(line)-1):
                    node1=line[i]
                    node2=line[i+1]
                    edge_detail = self.G[node1][node2]
                    edge_id= edge_detail["id_"]
                    #print(edge_id)
                    if edge_id in id_reuqire:
                        pass
                    else:
                        status=False
                #print(status)        
                if status:
                    new_line=[]
                    for i in range(len(line)-1):
                        node1=line[i]
                        node2=line[i+1]

                        if not new_line:
                            try:
                                new_line+=[node1,self.G[node1][node2]["label"],node2]
                            except:
                                print(node1, node2,line,line[i],line[i+1])
                        else:
                            try:
                                new_line+=[self.G[node1][node2]["label"],node2]
                            except:
                                print(node1, node2,line,line[i],line[i+1])
                else:
                    new_line=[]

                if new_line:
                    items.append(new_line)
            paths_shortest.append(items)
        
        # filter by label

        # build relation id to relation label dictionary
        relation_label=dict()
        for node1, node2 in self.G.edges:
            edge_detail=self.G[node1][node2]
            rel_id=edge_detail['id_']

            if rel_id in id_reuqire:
                temp=relation_label.get(rel_id,dict())

                label=edge_detail["label"]
                temp[label]=temp.get(label,0)+1
                relation_label[rel_id]=temp

        # choose the top 20 frequency relation and each relation label should also take 5%
        # check total number of triples for different relation id
        num_rel_id=dict()
        for rel_id in relation_label:
            num_rel_id[rel_id]=sum(relation_label[rel_id].values())
        
        relation_label_sort=dict()
        for rel_id in relation_label:
            label_num=relation_label[rel_id]
            sort_label = sorted(label_num.items(),key=lambda k:k[1], reverse=True)

            for label, num in sort_label[:20]:
                if num >= num_rel_id[rel_id]*0.01:
                    temp=relation_label_sort.get(rel_id, dict())
                    temp[label]=num
                    relation_label_sort[rel_id]=temp
        
        allowed_label=[]
        for key_ in relation_label_sort:
            allowed_label += list(relation_label_sort[key_])

        filtered_paths_length=[]
        for path_combine in paths_length:
            temp=[]
            for path in path_combine:
                length = len(path)
                relation_num = length//2

                count = 1
                pos= count*2-1
                status = True
                while pos < length:
                    rel_label= path[pos]

                    if rel_label not in allowed_label:
                        status = False
                        break

                    count+=1
                    pos= count*2-1

                if status:
                    temp.append(path)

            filtered_paths_length.append(temp)
        
        filtered_paths_shortest=[]
        for path_combine in paths_shortest:
            temp=[]
            for path in path_combine:
                length = len(path)
                relation_num = length//2

                count = 1
                pos= count*2-1
                status = True
                while pos < length:
                    rel_label= path[pos]

                    if rel_label not in allowed_label:
                        status = False
                        break

                    count+=1
                    pos= count*2-1

                if status:
                    temp.append(path)

            filtered_paths_shortest.append(temp)
            
        self.df["triples_len2"]=filtered_paths_length
        self.df["shortest_path"]=filtered_paths_shortest
        return self.df

# %%
# load cskg_dim
cskg_dim_head,cskg_dim_lines=load_source(cskg_dim_folder)
cskg_dim_lines[0]
# Out:
# ['/c/en/0-/r/DefinedAs-/c/en/empty_set-0000',
#  '/c/en/0',
#  '/r/DefinedAs',
#  '/c/en/empty_set',
#  '0',
#  'empty set',
#  'defined as',
#  'similarity',
#  'CN',
#  '[[0]] is the [[empty set]].']

# %% [markdown]
# # load train dataset

# %%
# load original data
QA=QAsystem(train_file)

# %%
QA.build_graph_cskg(cskg_dim_lines)

# %%
QA.add_cskg2QA()
# Out:
# 100%|██████████| 471/471 [00:05<00:00, 89.63it/s]
#                                          question     answer       qtype  \
# 0       what color is the cabinet in the kitchen?      black  color_room
# 1        what color is the picture in the office?      brown  color_room
# 2      what color is the sofa in the family room?  off-white  color_room
# 3       what color is the curtain in the hallway?  off-white  color_room
# 4           what color is the door in the closet?      white  color_room
# ...                                           ...        ...         ...
# 11268     what color is the table in the bedroom?        tan  color_room
# 11369      what color is the stool in the lounge?        tan  color_room
# 11370                    what color is the stool?        tan       color
# 11398          what room is the stool located in?     lounge    location
# 11430     what color is the chair in the hallway?       blue  color_room
#
#                    objects                                       triples_len2  \
# 0       [cabinet, kitchen]  [[cabinet, on top of, counter, by, kitchen], [...
# 1        [picture, office]  [[picture, above, train, has, office], [pictur...
# 2      [sofa, family_room]                                                 []
# 3       [curtain, hallway]  [[curtain, has, edge, of, hallway], [curtain, ...
# 4           [door, closet]  [[door, has a, handle, of, closet], [door, in,...
# ...                    ...                                                ...
# 11268     [table, bedroom]  [[table, in, floor, in, bedroom], [table, in, ...
# 11369      [stool, lounge]                                                 []
# 11370      [stool, lounge]                                                 []
# 11398      [stool, lounge]                                                 []
# 11430     [chair, hallway]  [[chair, at location, corner, of, hallway], [c...
#
#                                            shortest_path
# 0      [[cabinet, in, kitchen], [cabinet, above, cat,...
# 1      [[picture, above, train, has, office], [pictur...
# 2      [[sofa, next to, basket, behind, cat, at locat...
# 3      [[curtain, has, edge, of, hallway], [curtain, ...
# 4      [[door, in, back, of, closet], [door, behind, ...
# ...                                                  ...
# 11268  [[table, in, bedroom], [table, behind, baby, i...
# 11369                                                 []
# 11370                                                 []
# 11398                                                 []
# 11430  [[chair, by, cabinet, in, hallway], [chair, wi...
#
# [471 rows x 6 columns]

# %%
a=plt.hist([len(_) for _ in QA.df["triples_len2"]],log=True)
plt.title('Distribution for the number of paths for each question (Length 2 Path)')
plt.xlabel('Number of paths for each question')
plt.ylabel('Number of Question')
# Out:
# Text(0, 0.5, 'Number of Question')

# %%
a=plt.hist([len(_) for _ in QA.df["shortest_path"]],log=True)
plt.title('Distribution for the number of paths for each question (20 shortest paths)')
plt.xlabel('Number of paths for each question')
plt.ylabel('Number of Question')
# Out:
# Text(0, 0.5, 'Number of Question')

# %%
# count missing answer
print("length 2 path:",sum([len(_)==0 for _ in QA.df["triples_len2"]]))
print("shortest path:",sum([len(_)==0 for _ in QA.df["shortest_path"]]))
# Out:
# length 2 path: 168
# shortest path: 77

# %% [markdown]
# # Discard Room in Z position

# %%
# check the room name in EQA

rooms=set()
for object_, room in QA.df.objects:
    rooms.add(room)

# %%
# romove room Z, has
triples_len2_new=[]
shortest_path_new=[]

for triples1, triples2 in zip(QA.df.triples_len2, QA.df.shortest_path):
    new_triples1=[]
    new_triples2=[]
    
    for triple in triples1:
        if triple[2] in rooms or "room" in triple[2]:
            # romve room in Z position
            continue
            
        elif "has" in triple[1] or "has" in triple[3]:
            # romve "has" in relation
            continue
            
        else:
            new_triples1.append(triple)
            
    for triple in triples2:
        if triple[2] in rooms or "room" in triple[2]:
            continue
        else:
            new_triples2.append(triple)
            
    triples_len2_new.append(new_triples1)
    shortest_path_new.append(new_triples2)
    
QA.df["triples_len2"]=triples_len2_new
QA.df["shortest_path"]=shortest_path_new

# %% [markdown]
# # Build Wordnet Ontology

# %%
# build wordnet ontology
# load wordnet
wordnet_head,wordnet_lines=load_source(wordnet_file)
wordnet_lines[0]
# Out:
# ['wn:physical_entity.n.01',
#  '/r/IsA',
#  'wn:entity.n.01',
#  '"physical entity"',
#  '"entity"',
#  '"is a"',
#  '',
#  '"WN"']

# %%
# build graph
wordnet_g=nx.DiGraph()

# %%
id2label=defaultdict(set)

for line in wordnet_lines:
    if line[1]== "/r/IsA":
        node1=line[0].split(":")[1]
        node2=line[2].split(":")[1]
        node1_labels=line[3].replace('"',"").split("|")
        node2_labels=line[4].replace('"',"").split("|")
        id2label[node1]=id2label[node1].union(node1_labels)
        id2label[node2]=id2label[node2].union(node2_labels)
        
        if ".v." in node1 or ".v." in node1:
            continue
        wordnet_g.add_edge(node1,node2)
    else:
        continue

# %%
black_list={"room.n.02",'room.n.01',"food.n.01",'animal.n.01','person.n.01'}
new_black_list=set()
# check all sub class of blacklist

for item in black_list:
    temp=[item]
    while temp:
        new_temp=[]
        for issue in temp:
            new_temp+=[edge[0] for edge in wordnet_g.in_edges(issue)]
            
        new_temp_set=set(new_temp)
        new_black_list=new_black_list.union(new_temp_set)
        temp=new_temp_set

# %%
# check the blacklist label
blacklist_label=set()

for id_ in new_black_list:
    blacklist_label=blacklist_label.union(id2label[id_])

# %%
# filter by blacklist_label:
triples_len2_new=[]
shortest_path_new=[]
count=0

for triples1, triples2 in zip(QA.df.triples_len2, QA.df.shortest_path):
    new_triples1=[]
    new_triples2=[]
    
    for triple in triples1:
        if triple[2] in blacklist_label:
            count +=1
            continue
            
        else:
            new_triples1.append(triple)
            
    for triple in triples2:
        if triple[2] in blacklist_label:
            count +=1
            continue
        else:
            new_triples2.append(triple)
            
    triples_len2_new.append(new_triples1)
    shortest_path_new.append(new_triples2)

# %%
"woman" in blacklist_label
# Out:
# True

# %%
QA.df["triples_len2"]=triples_len2_new
QA.df["shortest_path"]=shortest_path_new
QA.df
# Out:
#                                          question     answer       qtype  \
# 0       what color is the cabinet in the kitchen?      black  color_room
# 1        what color is the picture in the office?      brown  color_room
# 2      what color is the sofa in the family room?  off-white  color_room
# 3       what color is the curtain in the hallway?  off-white  color_room
# 4           what color is the door in the closet?      white  color_room
# ...                                           ...        ...         ...
# 11268     what color is the table in the bedroom?        tan  color_room
# 11369      what color is the stool in the lounge?        tan  color_room
# 11370                    what color is the stool?        tan       color
# 11398          what room is the stool located in?     lounge    location
# 11430     what color is the chair in the hallway?       blue  color_room
#
#                    objects                                       triples_len2  \
# 0       [cabinet, kitchen]  [[cabinet, for, food, in, kitchen], [cabinet, ...
# 1        [picture, office]     [[picture, in, notebook, at location, office]]
# 2      [sofa, family_room]                                                 []
# 3       [curtain, hallway]  [[curtain, in, mirror, in, hallway], [curtain,...
# 4           [door, closet]  [[door, behind, bar, in, closet], [door, on, b...
# ...                    ...                                                ...
# 11268     [table, bedroom]  [[table, at location, corner, in, bedroom], [t...
# 11369      [stool, lounge]                                                 []
# 11370      [stool, lounge]                                                 []
# 11398      [stool, lounge]                                                 []
# 11430     [chair, hallway]  [[chair, at location, corner, of, hallway], [c...
#
#                                            shortest_path
# 0           [[cabinet, with, coffee_maker, in, kitchen]]
# 1      [[picture, above, train, has, office], [pictur...
# 2      [[sofa, next to, basket, behind, cat, at locat...
# 3      [[curtain, has, edge, of, hallway], [curtain, ...
# 4      [[door, behind, bar, in, closet], [door, on, b...
# ...                                                  ...
# 11268  [[table, near, bookshelf, at location, bedroom...
# 11369                                                 []
# 11370                                                 []
# 11398                                                 []
# 11430  [[chair, at location, corner, of, hallway], [c...
#
# [471 rows x 6 columns]

# %%
triples_len2_new[0]
# Out:
# [['cabinet', 'for', 'food', 'in', 'kitchen'],
#  ['cabinet', 'with', 'coffee_maker', 'in', 'kitchen'],
#  ['cabinet', 'above', 'fridge', 'at location', 'kitchen'],
#  ['cabinet', 'above', 'microwave_oven', 'at location', 'kitchen'],
#  ['cabinet', 'near', 'paper_towels', 'in', 'kitchen'],
#  ['cabinet', 'above', 'trash', 'at location', 'kitchen'],
#  ['cabinet', 'behind', 'desk', 'in', 'kitchen']]

# %%
# count missing answer
print("length 2 path:",sum([len(_)==0 for _ in QA.df["triples_len2"]]))
print("shortest path:",sum([len(_)==0 for _ in QA.df["shortest_path"]]))
# Out:
# length 2 path: 208
# shortest path: 121

# %% [markdown]
# # combine original question

# %%
def score(tokens_tensor):
    loss=model(tokens_tensor, labels=tokens_tensor)[0]
    return np.exp(loss.cpu().detach().numpy())

# %%
model = GPT2LMHeadModel.from_pretrained('gpt2')
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# %%
# check the average answer
count1=0
count2=0
sum_1=[]
sum_2=[]
for triples1, triples2 in zip(QA.df.triples_len2, QA.df.shortest_path):
    if len(triples1)>0:
        count1+=1
        
    if len(triples2)>0:
        count2+=1
    sum_1.append(len(triples1))
    sum_2.append(len(triples2))
    
print(sum(sum_1)/count1,sum(sum_2)/count2)
# Out:
# 5.357414448669202 4.1571428571428575

# %%
# build new sentence
num_choice=5
new_sentence=[]

for row in QA.df.iterrows():
    line=row[1]
    question_text=line.question
    object_=line.objects[0].replace("_"," ").replace("#"," ")
    
    question_templet=question_text.split(" "+object_)[0]+" "+object_+", which can be"
    question_templet2=question_text.split(" "+object_)[1]
    
    more_item=""
    
    if not line.triples_len2:
        new_sentence.append("")
        continue
    
    if len(line.triples_len2)>num_choice:
        triples=random.sample(line.triples_len2,num_choice)
    else:
        triples=line.triples_len2
    
    for triple in triples:
        relation=triple[1]
        item= triple[2]
        if not more_item:
            more_item+=relation + " a "+ item
        else:
            more_item += " or "+ relation+" a "+item
            
    sent=question_templet+" "+more_item+","+question_templet2
    sent.replace("_"," ").replace("?"," ")
    if sent[-2]==",":
        sent=sent[:-2]+"?"
    new_sentence.append(sent)

# %%
ques_sent=dict()
for question_text, sentence in zip(QA.df.question,new_sentence):
    ques_sent[question_text]=sentence

# %%
# add sentence to train

question_triple=dict()
#build dict
for row in QA.df.iterrows():
    question_text=row[1].question
    question_triple[question_text]=[row[1].triples_len2,row[1].shortest_path]

episodes=QA.train["episodes"]
for x in episodes:
    x['question']['len2Paths']=question_triple[x['question']['question_text']][0]
    x['question']['ShortestPath']=question_triple[x['question']['question_text']][1]
    x['question']['CombineSentence']=ques_sent[x['question']['question_text']]

QA.train["episodes"]=episodes

# %%
with open(train_file, 'w') as f:
    json.dump(QA.train, f)

# %%
# check the dump load is correct
with open(train_file, 'r') as f:
    train=json.load(f)

    # build dataframe for QA system
    episodes=train["episodes"]

    questions=[]
    qtypes=[]
    answers=[]
    objects=[]
    triples_len2=[]
    sents=[]
    for x in episodes:
        questions.append(x['question']['question_text'])
        answers.append(x['question']['answer_text'])
        qtypes.append(x['question']['question_type'])
        objects.append([x["goals"][0]["object_name"],x["goals"][0]["room_name"]])
        triples_len2.append(x['question']['len2Paths'])
        sents.append(x['question']['CombineSentence'])

    # build df
    data=zip(questions,answers,qtypes,objects,triples_len2,sents)
    df=pd.DataFrame(data)
    df.columns=['question', 'answer', 'qtype',"objects","triples_len2",'CombineSentence']

# %%
df
# Out:
#                                               question     answer       qtype  \
# 0            what color is the cabinet in the kitchen?      black  color_room
# 1             what color is the picture in the office?      brown  color_room
# 2           what color is the sofa in the family room?  off-white  color_room
# 3            what color is the curtain in the hallway?  off-white  color_room
# 4                what color is the door in the closet?      white  color_room
# ...                                                ...        ...         ...
# 11491             what room is the counter located in?    kitchen    location
# 11492             what room is the counter located in?    kitchen    location
# 11493          what color is the chair in the hallway?       blue  color_room
# 11494  what color is the fireplace in the family room?      white  color_room
# 11495        what color is the curtain in the kitchen?      brown  color_room
#
#                         objects  \
# 0            [cabinet, kitchen]
# 1             [picture, office]
# 2           [sofa, family_room]
# 3            [curtain, hallway]
# 4                [door, closet]
# ...                         ...
# 11491        [counter, kitchen]
# 11492        [counter, kitchen]
# 11493          [chair, hallway]
# 11494  [fireplace, family_room]
# 11495        [curtain, kitchen]
#
#                                             triples_len2  \
# 0      [[cabinet, for, food, in, kitchen], [cabinet, ...
# 1         [[picture, in, notebook, at location, office]]
# 2                                                     []
# 3      [[curtain, in, mirror, in, hallway], [curtain,...
# 4      [[door, behind, bar, in, closet], [door, on, b...
# ...                                                  ...
# 11491  [[counter, under, appliance, in, kitchen], [co...
# 11492  [[counter, under, appliance, in, kitchen], [co...
# 11493  [[chair, at location, corner, of, hallway], [c...
# 11494                                                 []
# 11495  [[curtain, in, image, of, kitchen], [curtain, ...
#
#                                          CombineSentence
# 0      what color is the cabinet, which can be near a...
# 1      what color is the picture, which can be in a n...
# 2
# 3      what color is the curtain, which can be in a m...
# 4      what color is the door, which can be in a phot...
# ...                                                  ...
# 11491  what room is the counter, which can be holding...
# 11492  what room is the counter, which can be holding...
# 11493  what color is the chair, which can be at locat...
# 11494
# 11495  what color is the curtain, which can be on a p...
#
# [11496 rows x 6 columns]

# %%
# check whether woman, man, girl in the combined sentence

for sent in tqdm(df.CombineSentence):
    for label in blacklist_label:
        if " "+label+" " in sent:
            print(label, sent)
# Out:
# 100%|██████████| 11496/11496 [00:28<00:00, 401.75it/s]

# %%
blacklist_label
# Out:
# {'hospital chaplain',
#  'cabbageworm',
#  'schnauzer',
#  'toolmaker',
#  'floor leader',
#  'whippet',
#  'Freemason',
#  'emperor butterfly',
#  'millet',
#  'Bavarian cream',
#  'mandator',
#  'mutineer',
#  'Unknown Soldier',
#  'telephone booth',
#  'Indian elephant',
#  'villainess',
#  'chewink',
#  'rock wallaby',
#  'tourist',
#  'linebacker',
#  'chambermaid',
#  'biscuit',
#  'impressionist',
#  'turtler',
#  'science teacher',
#  'aggressor',
#  'North American',
#  'sun tea',
#  'fatalist',
#  'won ton',
#  'putterer',
#  'fish meal',
#  'murder suspect',
#  'rusher',
#  'carpenter ant',
#  'summercaters',
#  'yellowfin',
#  'temporizer',
#  'orangeade',
#  'cuttlefish',
#  'conventioneer',
#  'chives',
#  'lemonade',
#  'case officer',
#  'buzzard',
#  'headroom',
#  'clairvoyant',
#  'tortricid',
#  'sister',
#  'forefather',
#  'slasher',
#  'technophobe',
#  'eohippus',
#  'Tom Thumb',
#  'night raven',
#  'heavy',
#  'dog in the manger',
#  'Appenzeller',
#  'greenwing',
#  'tanager',
#  'glass sponge',
#  'oilman',
#  'mastiff bat',
#  'doe',
#  'Laconian',
#  'fried egg',
#  'screwdriver',
#  'nonconformist',
#  'Irani',
#  'tunaburger',
#  'skillet fish',
#  'recovery room',
#  'drake',
#  'high-muck-a-muck',
#  'ginger ale',
#  'Kiowa',
#  'Brule',
#  'columnist',
#  'sand stargazer',
#  'paralegal',
#  'pigeon',
#  'bacon-lettuce-tomato sandwich',
#  'Southern Baptist',
#  'beef Wellington',
#  'herbalist',
#  'indigo bunting',
#  'collegian',
#  'poltroon',
#  'bolognese pasta sauce',
#  'knish',
#  'vacationer',
#  'percussionist',
#  'semolina',
#  'presiding officer',
#  'pastry cook',
#  'Amhara',
#  'flame fish',
#  'jail bird',
#  'mariner',
#  'Xhosa',
#  'pallid bat',
#  'pamphleteer',
#  'honest woman',
#  'scrubber',
#  'Vouvray',
#  'headmistress',
#  'cyborg',
#  'Hynerpeton bassetti',
#  'chatelaine',
#  'tiger cowrie',
#  'lake trout',
#  'antelope squirrel',
#  'Reynard',
#  'king mackerel',
#  'horse botfly',
#  'otter shrew',
#  'pursuer',
#  'traverser',
#  'whisperer',
#  'billiard player',
#  'lamellicorn beetle',
#  'Weizenbock',
#  'funambulist',
#  'civic leader',
#  'alleviator',
#  'Kansan',
#  'Hungarian partridge',
#  'Bhutanese',
#  'cavalryman',
#  'standard poodle',
#  'fritillary',
#  'glowworm',
#  'gaucho',
#  'Micmac',
#  'modern',
#  'materialist',
#  'sweetening',
#  'subtracter',
#  'crossopterygian',
#  'mincemeat',
#  'tortilla chip',
#  'taskmaster',
#  'smooth-haired fox terrier',
#  'licensed practical nurse',
#  'Lorenzo dressing',
#  'bay leaf',
#  'echidna',
#  'itch mite',
#  'flying gecko',
#  'political scientist',
#  'potto',
#  'stringer',
#  'instigator',
#  'dining-room attendant',
#  'demon',
#  'wool stapler',
#  'native speaker',
#  'golden retriever',
#  'false gavial',
#  'tick',
#  'Puerto Rican',
#  'beast of burden',
#  'Postimpressionist',
#  'pastis',
#  'rumpus room',
#  'standard-bearer',
#  'big brother',
#  'Welsh',
#  'cartoonist',
#  'bushwhacker',
#  'ephemerid',
#  'Olmec',
#  'mare',
#  'polluter',
#  'New World tapir',
#  'fruit fly',
#  'speckled rattlesnake',
#  'punkie',
#  'shoofly',
#  'speedskater',
#  'common opossum',
#  'greenshank',
#  'pochard',
#  'fingerling',
#  'Walker hound',
#  'visiting fireman',
#  'rustic',
#  'conditioner',
#  'pickle relish',
#  'wagoner',
#  'bad guy',
#  'clary sage',
#  'bullterrier',
#  'posturer',
#  'vanilla bean',
#  'alcoholic',
#  'sea squirt',
#  'street cleaner',
#  'earl',
#  'whistle blower',
#  'bovid',
#  'egalitarian',
#  'paratrooper',
#  'newscaster',
#  'appendicularia',
#  'dental technician',
#  'valley pocket gopher',
#  'volunteer',
#  'wren warbler',
#  'mercenary',
#  'extrovert',
#  'millionairess',
#  'dynamiter',
#  'graham bread',
#  'American crow',
#  'standardizer',
#  'seating',
#  'choline',
#  'primitive',
#  'South American poison toad',
#  'supplier',
#  'domestic llama',
#  'sulphur butterfly',
#  'Yankee',
#  'eau de vie',
#  'countertenor',
#  'Muslimah',
#  'sweetmeat',
#  'brush turkey',
#  'coucal',
#  'best man',
#  'mangabey',
#  'round whitefish',
#  'hadrosaur',
#  'eater',
#  'Atlantic manta',
#  'auk',
#  'great auk',
#  'allegorizer',
#  'apple juice',
#  'birch leaf miner',
#  'Philippian',
#  'father-figure',
#  'serologist',
#  'foster-mother',
#  'Zairese',
#  'point man',
#  'serjeant-at-law',
#  'tequila',
#  'goat cheese',
#  'botanist',
#  'manageress',
#  'Luxemburger',
#  'prosthodontist',
#  'pinche',
#  'Kusan',
#  'supermom',
#  'unguiculate',
#  'jumper',
#  'bacchant',
#  'lancelet',
#  'bottom dog',
#  'police dog',
#  'Knight Templar',
#  'hot-fudge sauce',
#  'Nebraskan',
#  'planula',
#  'featherweight',
#  'podicipitiform seabird',
#  'duffer',
#  'quietist',
#  'chough',
#  'hog sucker',
#  'pony',
#  'process-server',
#  'sea robin',
#  'processor',
#  'ideologist',
#  'daphnia',
#  'silkworm',
#  'spindlelegs',
#  'California newt',
#  'garlic bread',
#  'jewfish',
#  'halibut',
#  'Tom and Jerry',
#  'Mediterranean fruit fly',
#  'room clerk',
#  'sickbay',
#  'skidder',
#  'graduate nurse',
#  'namer',
#  'cicada',
#  'third baseman',
#  'false vampire',
#  'penguin',
#  'larvacean',
#  'Serbian',
#  'yellow bass',
#  'oncologist',
#  'Australopithecus africanus',
#  'molasses taffy',
#  'dispatcher',
#  'pre-Socratic',
#  'billfish',
#  'spectacled caiman',
#  'Walloon',
#  'wisent',
#  'mandatary',
#  'rani',
#  'ambusher',
#  'spaghetti',
#  'coroner',
#  'ship broker',
#  'bisque',
#  'Chief Constable',
#  'varied Lorikeet',
#  'click beetle',
#  'banded krait',
#  'Siberian husky',
#  'baboon',
#  'fruit punch',
#  'Reticulitermes lucifugus',
#  'apple jelly',
#  'guano bat',
#  'modifier',
#  'introvert',
#  'Molly Miller',
#  'bluethroat',
#  'dean',
#  'foster-sister',
#  'steamed pudding',
#  'detective',
#  'electrotherapist',
#  'spearhead',
#  'custodian',
#  "Mother Carey\\'s chicken",
#  'ouzo',
#  "lady\\'s maid",
#  'Kiliwa',
#  'eager beaver',
#  'douroucouli',
#  'landscape architect',
#  'invalidator',
#  'cheese spread',
#  'purser',
#  'dog-day cicada',
#  'abettor',
#  'pope',
#  'antiquary',
#  'Herr',
#  'pioneer',
#  'valentine',
#  'King of the Germans',
#  'has-been',
#  'ladylove',
#  'craftsman',
#  'fastener',
#  'spirula',
#  'grandstander',
#  'blanc',
#  'Great Russian',
#  'carnosaur',
#  'acarid',
#  'demander',
#  'remora',
#  'buddy',
#  'kelp greenling',
#  'Portuguese man-of-war',
#  'mammalogist',
#  'hyperope',
#  'tomato juice',
#  'stick cinnamon',
#  'oxtail soup',
#  'right whale',
#  'Asian',
#  'aerialist',
#  'swiftlet',
#  'mud turtle',
#  'side judge',
#  'guadalupe fur seal',
#  'chicken hawk',
#  'Brazilian',
#  'corn dab',
#  'page',
#  'Mennonite',
#  'vandal',
#  'housewrecker',
#  'votary',
#  'dancing-master',
#  'brass hat',
#  'spirit rapper',
#  'belt maker',
#  'piano teacher',
#  'warrant officer',
#  'rudapithecus',
#  'sir',
#  'brew',
#  'orderly',
#  'coral',
#  'fiduciary',
#  'flyweight',
#  'stone curlew',
#  'officiant',
#  'Hessian fly',
#  'aquatic bird',
#  'beaked salmon',
#  'oubliette',
#  'clothes moth',
#  'religionist',
#  'parricide',
#  'shoebill',
#  'lady',
#  'citizen',
#  'old lady',
#  'hermit crab',
#  'contralto',
#  'scorpaenid',
#  'buck sergeant',
#  'brunet',
#  'white-tailed jackrabbit',
#  'genus Argentinosaurus',
#  'bullfrog',
#  'placoderm',
#  'renter',
#  'embalmer',
#  'straw boss',
#  'hagiographer',
#  'adventuress',
#  'bean tostada',
#  'coach horse',
#  'sanderling',
#  'royal',
#  'mud dauber',
#  'green woodpecker',
#  'newspaper columnist',
#  'corporal',
#  'caraway seed bread',
#  "Steller\\'s sea cow",
#  'pledge taker',
#  'confectionery',
#  'chub mackerel',
#  'public relations person',
#  'quintipara',
#  'Life Saver',
#  'muckraker',
#  'fox squirrel',
#  'Rocky Mountain jay',
#  'Mohican',
#  'coon',
#  'procellariiform seabird',
#  'White',
#  'Cardigan',
#  'troubleshooter',
#  'swindler',
#  'talapoin',
#  'pickpocket',
#  'foundling',
#  'three-toed sloth',
#  'common scoter',
#  'barnburner',
#  'attacker',
#  'ironmonger',
#  'Lithuanian',
#  'disk jockey',
#  'sloucher',
#  'scarlet tanager',
#  'Fauntleroy',
#  'chicken roundworm',
#  'sender',
#  'criminologist',
#  'agnate',
#  'fugleman',
#  'rice',
#  'bachelor girl',
#  'chartist',
#  'Tungusic',
#  'serial killer',
#  'partaker',
#  'tomboy',
#  'importer',
#  'oneiromancer',
#  'penologist',
#  'sob sister',
#  'bark beetle',
#  'spiny puffer',
#  'woolly apple aphid',
#  'deaf person',
#  'electric catfish',
#  'whirligig beetle',
#  'sapsago',
#  'goalkeeper',
#  'miniature poodle',
#  'Sunnite',
#  'ichthyologist',
#  'Tantrist',
#  'nurse shark',
#  'anomalops',
#  'cider',
#  'grenadier',
#  'beroe',
#  'creole-fish',
#  'learner',
#  'aviator',
#  'Myxinikela siroka',
#  'ice cream',
#  'nuclear physicist',
#  'osteopath',
#  'sleepwalker',
#  'stockist',
#  'pink lady',
#  'bull mastiff',
#  'killer bee',
#  'nutmeg',
#  'emergency room',
#  'red jungle fowl',
#  'mustard sauce',
#  'Wykehamist',
#  'carhop',
#  'Seeing Eye dog',
#  'greater pichiciego',
#  'European black grouse',
#  'chicken paprika',
#  'stepson',
#  'skate',
#  "Bullock\\'s oriole",
#  'electric eel',
#  'eland',
#  'galvanizer',
#  'Nicaraguan',
#  'clubroom',
#  'auditor',
#  'bridge player',
#  'curly-coated retriever',
#  'caddisworm',
#  'narcissist',
#  'congee',
#  'apparatchik',
#  'Franco-American',
#  'advisee',
#  'Inca',
#  'governor',
#  'dusky-footed woodrat',
#  'desert iguana',
#  'Yemeni',
#  'American shrew mole',
#  'deviled egg',
#  'Esquire',
#  'hydromel',
#  'red poll',
#  'Peking man',
#  'anoa',
#  'acidophilus milk',
#  'mosquito',
#  'percoid fish',
#  'wood-frog',
#  'Druze',
#  'sable antelope',
#  'beadle',
#  'press photographer',
#  'bullhead',
#  'web spinner',
#  'shortfin mako',
#  'common shrew',
#  'yellowfin croaker',
#  'cotinga',
#  'Taiwanese',
#  'garlic',
#  'blue racer',
#  'white-bellied swallow',
#  'ghee',
#  'cloakmaker',
#  'trombonist',
#  'Maoist',
#  'plum sauce',
#  'Secretary of Housing and Urban Development',
#  'candy egg',
#  'farm horse',
#  'firewater',
#  'plowboy',
#  'miser',
#  'tenrec',
#  'chicken soup',
#  'westerner',
#  'washerman',
#  'Winnebago',
#  'Sihasapa',
#  'male horse',
#  'left fielder',
#  'applicant',
#  'catalufa',
#  'samurai',
#  'pushover',
#  'colonial',
#  'English person',
#  'inventor',
#  'piping plover',
#  'water rat',
#  'snarer',
#  'gandy dancer',
#  'bombardier',
#  'waxwing',
#  'mezzo-soprano',
#  'black rat snake',
#  'voice',
#  'Slovak',
#  'pusher',
#  'investment adviser',
#  'neurologist',
#  'game fish',
#  'taguan',
#  'Pomeranian',
#  'Janissary',
#  'Texan',
#  'White Russian',
#  'Belgian hare',
#  'screenwriter',
#  'Lord of Misrule',
#  'changer',
#  'thrush nightingale',
#  'trapper',
#  'delinquent',
#  'litterer',
#  'passerine',
#  'hepatic tanager',
#  'logical positivist',
#  'eastern narrow-mouthed toad',
#  'turkey',
#  'harbor porpoise',
#  'butty',
#  'beneficiary',
#  'tub-thumper',
#  'highbrow',
#  'lodger',
#  'hyrax',
#  'perfecter',
#  'Chickasaw',
#  'lesser rorqual',
#  'emperor',
#  'eastern kingbird',
#  'coureur de bois',
#  'caricaturist',
#  'Chihuahua',
#  'grenadine',
#  'cayuse',
#  'tailed frog',
#  'worker bee',
#  'dorbeetle',
#  'winker',
#  'Lombard',
#  'honey bun',
#  'slave ant',
#  'Marxist',
#  'mew',
#  'pesto',
#  'Skagit',
#  'rainbow seaperch',
#  'accessory after the fact',
#  'fossa',
#  'ephemeron',
#  'Pretender',
#  'scrubbird',
#  'encyclopedist',
#  'monk',
#  'transplanter',
#  'field marshal',
#  'tamarisk gerbil',
#  'Welshman',
#  'Don Quixote',
#  'interlocutor',
#  'flying phalanger',
#  'paella',
#  'Kraut',
#  'dancer',
#  'disturber',
#  'punster',
#  'chicken',
#  'ordainer',
#  'censor',
#  'Shoshone',
#  'annotator',
#  'Pekinese',
#  'pavlova',
#  'exarch',
#  'junior featherweight',
#  'consort',
#  'postmaster',
#  'kleptomaniac',
#  'deinonychus',
#  'girl Friday',
#  'prancer',
#  'voluptuary',
#  'cigar smoker',
#  'dickeybird',
#  'greenhouse whitefly',
#  'gopher snake',
#  'Brother',
#  'quadruped',
#  'provost',
#  'dwarf',
#  'revenuer',
#  'wallah',
#  'narthex',
#  'smoking room',
#  'hospital room',
#  'Virgin Mary',
#  'cover girl',
#  'Uruguay potato',
#  'emerald shiner',
#  'papaya juice',
#  'whirling dervish',
#  'ascender',
#  'stabber',
#  'Hare Krishna',
#  'postulant',
#  'Kirghiz',
#  'flight surgeon',
#  'hooker',
#  'bluefish',
#  'bonito',
#  'promoter',
#  'invalid',
#  'laughing owl',
#  'desert tortoise',
#  'cockle',
#  'brother-in-law',
#  'hall',
#  'compiler',
#  'soup du jour',
#  'slicer',
#  'lotus-eater',
#  'staghound',
#  'Grand Inquisitor',
#  'serotine',
#  'special',
#  'pasha',
#  'wild duck',
#  'ladybug',
#  'rabbit',
#  'tattler',
#  'watcher',
#  'perceiver',
#  'visitor',
#  'counselor',
#  'Smitane',
#  'night snake',
#  'peripatetic',
#  'cankerworm',
#  'policeman',
#  'acquaintance',
#  'black-tailed deer',
#  'cartwright',
#  'clumsy person',
#  'villager',
#  'Dutch uncle',
#  'insured',
#  'chambered nautilus',
#  'Merostomata',
#  'bottom-feeder',
#  'Fauve',
#  'blacktip shark',
#  'cousin',
#  'deer',
#  'caroler',
#  'latchkey child',
#  'matelote',
#  'gentleman-at-arms',
#  'Malayan tapir',
#  'Vietnamese',
#  'low-fat milk',
#  'intruder',
#  'commander',
#  'defecator',
#  'water moccasin',
#  'agama',
#  'double agent',
#  'draper',
#  'crossbill',
#  'Coue',
#  'diarist',
#  'marine iguana',
#  'fighter pilot',
#  'bock',
#  'song thrush',
#  'peach melba',
#  'mulligan stew',
#  'little egret',
#  'Indian giver',
#  'Baltimore oriole',
#  'strider',
#  'Treasury',
#  'good person',
#  'Lao',
#  'monotreme',
#  'broadbill',
#  'recreation room',
#  'dosser',
#  'party girl',
#  'carbohydrate loading',
#  'scene painter',
#  'gonif',
#  'newsagent',
#  "ladies\\' room",
#  'sneak thief',
#  'Panamanian',
#  'shipmate',
#  'glossy snake',
#  'successor',
#  'collie',
#  'swan',
#  'oblate',
#  'mourner',
#  'canned meat',
#  'refectory',
#  'brit',
#  'chemist',
#  'salmon',
#  'Old Catholic',
#  'danseur',
#  'mite',
#  'Dominican',
#  'Edo',
#  'cranberry sauce',
#  'manta',
#  'inamorato',
#  'ally',
#  'postdoc',
#  'black crappie',
#  "planter\\'s punch",
#  'sex symbol',
#  'sour cream',
#  'wafer',
#  'cobber',
#  'Libra',
#  'games-master',
#  'actor',
#  'claustrophobe',
#  'Sicilian',
#  'peachick',
#  'strongroom',
#  'weekend warrior',
#  'minor leaguer',
#  'Miniconju',
#  'pease pudding',
#  'rum sling',
#  'ginger',
#  'cultural attache',
#  'pawer',
#  'larcenist',
#  'kaki',
#  'fox terrier',
#  'Pharisee',
#  'baked Alaska',
#  'Italian greyhound',
#  'conchologist',
#  'bank martin',
#  'rissole',
#  'general practitioner',
#  'freetail',
#  'half-and-half',
#  'briard',
#  'soldier',
#  'tovarich',
#  'piece de resistance',
#  'herrerasaur',
#  'scenarist',
#  'Fasciolopsis buski',
#  'dusky shark',
#  'logician',
#  'partner',
#  'crackpot',
#  'crewman',
#  'porcupine',
#  'insect',
#  'boss',
#  'multi-billionaire',
#  'incubus',
#  'governor general',
#  'roller-skater',
#  'mollycoddle',
#  'apple turnover',
#  'war criminal',
#  'crayfish',
#  'bombardier beetle',
#  'ghostwriter',
#  'gull',
#  'alligatorfish',
#  'gall wasp',
#  'wood pigeon',
#  'palace',
#  'scrod',
#  'behaviorist',
#  'Aborigine',
#  'saurian',
#  'skilled worker',
#  'common brant goose',
#  'limpet',
#  'vulture',
#  'geneticist',
#  'tinamou',
#  'caprimulgiform bird',
#  'tyrannosaur',
#  'Durham',
#  'scavenger',
#  'Javanese',
#  'blackfish',
#  'petitioner',
#  'herder',
#  'tuatara',
#  'Maidu',
#  'swinger',
#  'fabulist',
#  'whitey',
#  'great white heron',
#  'stepmother',
#  'headhunter',
#  'Secretary of Veterans Affairs',
#  'great-niece',
#  'dark bread',
#  'signorina',
#  'shuffler',
#  'founder',
#  'monarchist',
#  'senior master sergeant',
#  'Hermissenda crassicornis',
#  'timekeeper',
#  'old-age pensioner',
#  'indigo snake',
#  'stonefly',
#  'Junker',
#  'kidnapper',
#  'Heidelberg man',
#  'conveyancer',
#  'long-horned beetle',
#  'Irish soda bread',
#  'timothy',
#  'countrywoman',
#  'bacteriologist',
#  'wheat germ',
#  'barbecue sauce',
#  'orange peel',
#  'Shakespearian',
#  'Spanish rice',
#  'stomatopod',
#  'mushy peas',
#  'Regius professor',
#  "men\\'s room",
#  'dog catcher',
#  'Pinot blanc',
#  'petty officer',
#  'cardroom',
#  'helmsman',
#  'couchette',
#  'booklouse',
#  'warrantee',
#  'Englishwoman',
#  'crucian carp',
#  'farmer',
#  'Algerian',
#  'mosquitofish',
#  'goldeneye',
#  'escapist',
#  'group captain',
#  'scapegrace',
#  'waterdog',
#  'belfry',
#  'kaiser roll',
#  'commissioned officer',
#  'anteater',
#  'television reporter',
#  'war correspondent',
#  'cascades frog',
#  'fry cook',
#  'Muskogee',
#  'hare',
#  'accused',
#  'prodigy',
#  'falconer',
#  'oatcake',
#  'water vole',
#  'little owl',
#  'grantor',
#  'bondman',
#  'midwife',
#  'wood rat',
#  'creature',
#  'sailfish',
#  'ringleader',
#  'important person',
#  'chutney',
#  'bookmaker',
#  'skin-diver',
#  'musteline mammal',
#  'macho',
#  'hockey player',
#  'synapsid',
#  'imperialist',
#  'federalist',
#  'crossing guard',
#  'black marlin',
#  ...}

# %%
new_sentence_set=set(new_sentence)

# %%
sentence_score=[]

for sent in new_sentence_set:
    if sent == "":
        continue
    tokens_tensor = tokenizer.encode(sent, add_special_tokens=False, return_tensors="pt")
    result_score=score(tokens_tensor)
    sentence_score.append([sent,result_score])

# %% [markdown]
# # load val dataset

# %%
QA=QAsystem(val_file)
QA.build_graph_cskg(cskg_dim_lines)
QA.add_cskg2QA()
# Out:
# 100%|██████████| 114/114 [00:01<00:00, 85.86it/s]
#                                         question       answer       qtype  \
# 0       what color is the picture in the closet?        brown  color_room
# 8     what color is the shelving in the hallway?        brown  color_room
# 13         what color is the door in the office?        white  color_room
# 22         what color is the door in the closet?        brown  color_room
# 24    what color is the curtain in the bathroom?    off-white  color_room
# ...                                          ...          ...         ...
# 1805       what room is the wardrobe located in?          gym    location
# 1826       what room is the tv stand located in?  family room    location
# 1852   what color is the cabinet in the bedroom?        brown  color_room
# 1855            what color is the clothes dryer?        white       color
# 1913            what room is the bed located in?      bedroom    location
#
#                             objects  \
# 0                 [picture, closet]
# 8               [shelving, hallway]
# 13                   [door, office]
# 22                   [door, closet]
# 24              [curtain, bathroom]
# ...                             ...
# 1805                [wardrobe, gym]
# 1826        [tv#stand, family_room]
# 1852             [cabinet, bedroom]
# 1855  [clothes#dryer, laundry_room]
# 1913                 [bed, bedroom]
#
#                                            triples_len2  \
# 0     [[picture, on top of, bar, in, closet], [pictu...
# 8                                                    []
# 13    [[door, above, building, has, office], [door, ...
# 22    [[door, has a, handle, of, closet], [door, in,...
# 24    [[curtain, has a, house, has a, bathroom], [cu...
# ...                                                 ...
# 1805                                                 []
# 1826                                                 []
# 1852  [[cabinet, above, television, in, bedroom], [c...
# 1855                                                 []
# 1913  [[bed, above, couch, in, bedroom], [bed, on to...
#
#                                           shortest_path
# 0     [[picture, on top of, bar, in, closet], [pictu...
# 8                                                    []
# 13    [[door, by, office], [door, above, building, h...
# 22    [[door, in, back, of, closet], [door, behind, ...
# 24    [[curtain, behind, clock, in, bathroom], [curt...
# ...                                                 ...
# 1805                                                 []
# 1826                                                 []
# 1852  [[cabinet, in, bedroom], [cabinet, in, backgro...
# 1855                                                 []
# 1913  [[bed, in, bedroom], [bed, under, baby, in, be...
#
# [114 rows x 6 columns]

# %%
# check the room name in EQA

rooms=set()
for object_, room in QA.df.objects:
    rooms.add(room)
    
# romove room Z, has
triples_len2_new=[]
shortest_path_new=[]

for triples1, triples2 in zip(QA.df.triples_len2, QA.df.shortest_path):
    new_triples1=[]
    new_triples2=[]
    
    for triple in triples1:
        if triple[2] in rooms or "room" in triple[2]:
            # romve room in Z position
            continue
            
        elif "has" in triple[1] or "has" in triple[3]:
            # romve "has" in relation
            continue
            
        else:
            new_triples1.append(triple)
            
    for triple in triples2:
        if triple[2] in rooms or "room" in triple[2]:
            continue
        else:
            new_triples2.append(triple)
            
    triples_len2_new.append(new_triples1)
    shortest_path_new.append(new_triples2)
    
QA.df["triples_len2"]=triples_len2_new
QA.df["shortest_path"]=shortest_path_new


# filter by blacklist_label:
triples_len2_new=[]
shortest_path_new=[]
count=0

for triples1, triples2 in zip(QA.df.triples_len2, QA.df.shortest_path):
    new_triples1=[]
    new_triples2=[]
    
    for triple in triples1:
        if triple[2] in blacklist_label:
            count +=1
            continue
            
        else:
            new_triples1.append(triple)
            
    for triple in triples2:
        if triple[2] in blacklist_label:
            count +=1
            continue
        else:
            new_triples2.append(triple)
            
    triples_len2_new.append(new_triples1)
    shortest_path_new.append(new_triples2)

# %%
QA.df["triples_len2"]=triples_len2_new
QA.df["shortest_path"]=shortest_path_new
QA.df
# Out:
#                                         question       answer       qtype  \
# 0       what color is the picture in the closet?        brown  color_room
# 8     what color is the shelving in the hallway?        brown  color_room
# 13         what color is the door in the office?        white  color_room
# 22         what color is the door in the closet?        brown  color_room
# 24    what color is the curtain in the bathroom?    off-white  color_room
# ...                                          ...          ...         ...
# 1805       what room is the wardrobe located in?          gym    location
# 1826       what room is the tv stand located in?  family room    location
# 1852   what color is the cabinet in the bedroom?        brown  color_room
# 1855            what color is the clothes dryer?        white       color
# 1913            what room is the bed located in?      bedroom    location
#
#                             objects  \
# 0                 [picture, closet]
# 8               [shelving, hallway]
# 13                   [door, office]
# 22                   [door, closet]
# 24              [curtain, bathroom]
# ...                             ...
# 1805                [wardrobe, gym]
# 1826        [tv#stand, family_room]
# 1852             [cabinet, bedroom]
# 1855  [clothes#dryer, laundry_room]
# 1913                 [bed, bedroom]
#
#                                            triples_len2  \
# 0     [[picture, on top of, bar, in, closet], [pictu...
# 8                                                    []
# 13    [[door, on, heater, at location, office], [doo...
# 22    [[door, behind, bar, in, closet], [door, on, b...
# 24    [[curtain, behind, clock, in, bathroom], [curt...
# ...                                                 ...
# 1805                                                 []
# 1826                                                 []
# 1852  [[cabinet, above, television, in, bedroom], [c...
# 1855                                                 []
# 1913  [[bed, above, couch, in, bedroom], [bed, with,...
#
#                                           shortest_path
# 0     [[picture, on top of, bar, in, closet], [pictu...
# 8                                                    []
# 13    [[door, above, building, has, office], [door, ...
# 22    [[door, behind, bar, in, closet], [door, on, b...
# 24    [[curtain, behind, clock, in, bathroom], [curt...
# ...                                                 ...
# 1805                                                 []
# 1826                                                 []
# 1852  [[cabinet, in, background, in, bedroom], [cabi...
# 1855                                                 []
# 1913  [[bed, in, background, in, bedroom], [bed, nea...
#
# [114 rows x 6 columns]

# %%
# check the average answer
count1=0
count2=0
sum_1=[]
sum_2=[]
for triples1, triples2 in zip(QA.df.triples_len2, QA.df.shortest_path):
    if len(triples1)>0:
        count1+=1
        
    if len(triples2)>0:
        count2+=1
    sum_1.append(len(triples1))
    sum_2.append(len(triples2))
    
print(sum(sum_1)/count1,sum(sum_2)/count2)
# Out:
# 6.166666666666667 3.7228915662650603

# %%
# build new sentence
num_choice=5
new_sentence=[]


for row in QA.df.iterrows():
    line=row[1]
    question_text=line.question
    object_=line.objects[0].replace("_"," ").replace("#"," ")
    
    question_templet=question_text.split(" "+object_)[0]+" "+object_+", which can be"
    question_templet2=question_text.split(" "+object_)[1]
    
    more_item=""
    
    if not line.triples_len2:
        new_sentence.append("")
        continue
    
    if len(line.triples_len2)>num_choice:
        triples=random.sample(line.triples_len2,num_choice)
    else:
        triples=line.triples_len2
    
    for triple in triples:
        relation=triple[1]
        item= triple[2]
        if not more_item:
            more_item+=relation + " a "+ item
        else:
            more_item += " or "+ relation+" a "+item
            
    sent=question_templet+" "+more_item+","+question_templet2
    sent.replace("_"," ").replace("?"," ")
    if sent[-2]==",":
        sent=sent[:-2]+"?"
    new_sentence.append(sent)

# %%
len(new_sentence)
# Out:
# 114

# %%
new_sentence_set=new_sentence_set.union(set(new_sentence))

# %%
sentence_score=[]

for sent in new_sentence_set:
    if sent == "":
        continue
    tokens_tensor = tokenizer.encode(sent, add_special_tokens=False, return_tensors="pt")
    result_score=score(tokens_tensor)
    sentence_score.append([sent,result_score])

# %%
# save
ques_sent=dict()
for question_text, sentence in zip(QA.df.question,new_sentence):
    ques_sent[question_text]=sentence
    
# add sentence to train

question_triple=dict()
#build dict
for row in QA.df.iterrows():
    question_text=row[1].question
    question_triple[question_text]=[row[1].triples_len2,row[1].shortest_path]

episodes=QA.train["episodes"]
for x in episodes:
    x['question']['len2Paths']=question_triple[x['question']['question_text']][0]
    x['question']['ShortestPath']=question_triple[x['question']['question_text']][1]
    x['question']['CombineSentence']=ques_sent[x['question']['question_text']]

QA.train["episodes"]=episodes

# %%
with open(val_file, 'w') as f:
    json.dump(QA.train, f)

# %%
# check the dump load is correct
with open(val_file, 'r') as f:
    train=json.load(f)

    # build dataframe for QA system
    episodes=train["episodes"]

    questions=[]
    qtypes=[]
    answers=[]
    objects=[]
    triples_len2=[]
    sents=[]
    for x in episodes:
        questions.append(x['question']['question_text'])
        answers.append(x['question']['answer_text'])
        qtypes.append(x['question']['question_type'])
        objects.append([x["goals"][0]["object_name"],x["goals"][0]["room_name"]])
        triples_len2.append(x['question']['len2Paths'])
        sents.append(x['question']['CombineSentence'])

    # build df
    data=zip(questions,answers,qtypes,objects,triples_len2,sents)
    df=pd.DataFrame(data)
    df.columns=['question', 'answer', 'qtype',"objects","triples_len2",'CombineSentence']

# %%
df
# Out:
#                                       question       answer       qtype  \
# 0     what color is the picture in the closet?        brown  color_room
# 1     what color is the picture in the closet?        brown  color_room
# 2     what color is the picture in the closet?        brown  color_room
# 3     what color is the picture in the closet?        brown  color_room
# 4     what color is the picture in the closet?        brown  color_room
# ...                                        ...          ...         ...
# 1945          what room is the bed located in?      bedroom    location
# 1946     what room is the tv stand located in?  family room    location
# 1947     what room is the tv stand located in?  family room    location
# 1948          what room is the bed located in?      bedroom    location
# 1949          what room is the bed located in?      bedroom    location
#
#                       objects  \
# 0           [picture, closet]
# 1           [picture, closet]
# 2           [picture, closet]
# 3           [picture, closet]
# 4           [picture, closet]
# ...                       ...
# 1945           [bed, bedroom]
# 1946  [tv#stand, family_room]
# 1947  [tv#stand, family_room]
# 1948           [bed, bedroom]
# 1949           [bed, bedroom]
#
#                                            triples_len2  \
# 0     [[picture, on top of, bar, in, closet], [pictu...
# 1     [[picture, on top of, bar, in, closet], [pictu...
# 2     [[picture, on top of, bar, in, closet], [pictu...
# 3     [[picture, on top of, bar, in, closet], [pictu...
# 4     [[picture, on top of, bar, in, closet], [pictu...
# ...                                                 ...
# 1945  [[bed, above, couch, in, bedroom], [bed, with,...
# 1946                                                 []
# 1947                                                 []
# 1948  [[bed, above, couch, in, bedroom], [bed, with,...
# 1949  [[bed, above, couch, in, bedroom], [bed, with,...
#
#                                         CombineSentence
# 0     what color is the picture, which can be on top...
# 1     what color is the picture, which can be on top...
# 2     what color is the picture, which can be on top...
# 3     what color is the picture, which can be on top...
# 4     what color is the picture, which can be on top...
# ...                                                 ...
# 1945  what room is the bed, which can be near a lamp...
# 1946
# 1947
# 1948  what room is the bed, which can be near a lamp...
# 1949  what room is the bed, which can be near a lamp...
#
# [1950 rows x 6 columns]

# %%
# check whether woman, man, girl in the combined sentence

for sent in df.CombineSentence:
    for label in blacklist_label:
        if " "+label+" " in sent:
            print(label, sent)

# %%
"girl" in blacklist_label
# Out:
# True

# %%
len(episodes)
# Out:
# 1950

# %%
sort_sentence_score=sorted(sentence_score,key=lambda k:int(k[1]))
sort_sentence_score[:10]
# Out:
# [['what color is the stove, which can be next to a fridge or next to a knife or in a countertop or in a corner or in a island, in the kitchen?',
#   36.22326],
#  ['what color is the cabinet, which can be above a television or behind a table or behind a couch or next to a fireplace or behind a bed, in the bedroom?',
#   37.10165],
#  ['what color is the stove, which can be in a countertop or next to a fridge or next to a knife or in a picture or on a trash, in the kitchen?',
#   40.187485],
#  ['what color is the curtain, which can be above a bed or by a shelf or behind a couch or in a mirror or behind a television, in the bedroom?',
#   42.0842],
#  ['what color is the picture, which can be on top of a bar or of a blanket or for a container or above a pillow or on a shirt, in the closet?',
#   43.84065],
#  ['what color is the picture, which can be on a ceiling, in the hallway?',
#   43.64959],
#  ['what color is the stove, which can be on a trash or next to a fridge or in a countertop or in a corner or next to a knife?',
#   44.766582],
#  ['what color is the picture, which can be in a notebook, in the office?',
#   46.867992],
#  ['what color is the toaster, which can be near a coffee_maker or next to a container or in a corner or on a dryer or next to a pan, in the kitchen?',
#   46.820007],
#  ['what color is the stove, which can be next to a knife or in a corner or in a island or next to a fridge or in a countertop?',
#   48.252525]]

# %%
# draw a score graph
y=[_[1] for _ in sort_sentence_score]
x= range(len(sort_sentence_score))

plt.xlabel('Rank of the Sort')
plt.ylabel('Perplexity of Sentences')
plt.plot(x,y,'r--',label='type1')
